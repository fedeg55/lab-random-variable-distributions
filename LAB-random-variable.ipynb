# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %% [markdown]
# 1. Use the numerical variables from our dataset this week.
# 2. Check using a distribution plot if the variables fit the theoretical normal or exponential distribution.
# 3. Check if any of the transformations (log-transform, etc.) we have seen up to this point changes the result.

# %%
df = pd.read_csv('numerical.csv')

# %%
df
# Out:
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                 6979.535903       0                    94
# 1                12887.431650   48767                   108
# 2                 7645.861827       0                   106
# 3                 2813.692575   43836                    73
# 4                 8256.297800   62902                    69
# ...                       ...     ...                   ...
# 8187              4100.398533   47761                   104
# 8188             23405.987980   71941                    73
# 8189              3096.511217   21604                    79
# 8190              8163.890428       0                    85
# 8191              2611.836866       0                    77
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                          13                             42
# 1                          18                             38
# ...

# %%
for column in df:     
    sns.displot(df[column], bins=30, kde=True)
plt.show()

# %%
df1 = df.apply(lambda x: np.where(x > 0, np.log(x), x))
# Out:
# C:\Users\fede_\anaconda3\Lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
for column in df1:     
    sns.displot(df1[column], bins=30, kde=True)
plt.show()

# %% [markdown]
# None of thwem looks like a normal distribution besides the total_claim_amount after log. And income (forgetting about the 0) has a poisson correlation
